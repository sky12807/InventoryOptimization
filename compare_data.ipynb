# %%
import numpy as np
import netCDF4 as nc
import glob
from copy import deepcopy
import matplotlib.pyplot as plt

# %%
org_data1 = []
org_data2 = []
# for i in range(91,100):
#     org_data1.append(nc.Dataset(f'/AS_data/Emission/EM_20150{i}', 'r'))
#     org_data2.append(nc.Dataset(f'/scratch/tmp/EM_copy_new/EM_20150{i}', 'r'))
for i in range(274,305):
    org_data1.append(nc.Dataset(f'/AS_data/Emission/EM_2015{i}', 'r'))
    org_data2.append(nc.Dataset(f'/scratch/tmp/EM_copy_new/EM_2015{i}', 'r'))

# %%
data1 = [d.variables for d in org_data1]
data2 = [d.variables for d in org_data2]

# %%
p1 = [d['ALD2'][:-1] for d in data1]
p2 = [d['AlD2'][:-1] for d in data2]

# %%
d1 = np.concatenate(p1,axis = 0)
d2 = np.concatenate(p2,axis = 0)

# %%
d1 = np.sum(d1,axis=1)
d2 = np.sum(d2,axis=1)

# %%
for b,a,name in [[136,115,'beijing'],[139,112,'tianjin'],[130,107,'shijiazhuang'],[157,76,'ningbo'],[96,99,'lanzhou'],[112,91,'xian']]:
#     plt.plot(con_data[:,5,a,b],'--')
#     plt.show()
#     plt.plot(fin_data[:,5,a,b],'--')
#     plt.show()
#     plt.plot(rest_data[:,5,a,b],'--')
#     plt.legend(['before','after','final'])
#     plt.show()
    print('*'*20)
    plt.rcParams['figure.figsize'] = (15, 5)
    plt.plot(d1[:,a,b],'--')
    plt.plot(d2[:,a,b])
    plt.show()
# Out:
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************

# %%
ctm_data = nc.Dataset(f'/scratch/tmp/liusong/COMBINE_ACONC_v521_intel_microsoft_201510.nc','r')
c_data = ctm_data.variables

# %%
c = c_data['ETH']

# %%
obs = np.load('/AS_data/obs_npy/obs2015_10_744_6_182_232.npy')

# %%
obs.shape
# Out:
# (744, 6, 182, 232)

# %%
for b,a,name in [[136,115,'beijing'],[139,112,'tianjin'],[130,107,'shijiazhuang'],[157,76,'ningbo'],[96,99,'lanzhou'],[112,91,'xian']]:
#     plt.plot(con_data[:,5,a,b],'--')
#     plt.show()
#     plt.plot(fin_data[:,5,a,b],'--')
#     plt.show()
#     plt.plot(rest_data[:,5,a,b],'--')
#     plt.legend(['before','after','final'])
#     plt.show()
    print('*'*20)
    plt.rcParams['figure.figsize'] = (15, 5)
    plt.plot(d[:,0,a,b],'--')
    plt.plot(c[:,0,a,b])
    plt.show()
# Out:
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************

# %%
new_ctm_data = nc.Dataset(f'/scratch/tmp/liusong/COMBINE_ACONC_v521_intel_microsoft_201510.nc','r')
new_ctm = new_ctm_data.variables
new_ctm_list = [new_ctm[i] for i in ["NO2","SO2","O3","PM25_TOT","PM10","CO"]]
new_ctm = np.concatenate(new_ctm_list,axis = 1)

# %%
ctm = np.load('/AS_data/Conc_npy/TOTAL_2015_10_NO2_SO2_O3_PM25_PM10_CO__744_6_182_232.npy')

# %%
obs = np.load('/AS_data/obs_npy/obs2015_10_744_6_182_232.npy')

# %%
temp = obs.copy()
obs[temp==-999] = np.nan

# %%
p_name = ["NO2","SO2","O3","PM25_TOT","PM10","CO"]
for i in range(4):
#     for b,a,name in [[136,115,'beijing'],[139,112,'tianjin'],[130,107,'shijiazhuang'],[157,76,'ningbo'],[96,99,'lanzhou'],[112,91,'xian']]:
    for b,a,name in [[114,26,'sanya'],[140,82,'hefei'],[155,81,'shanghai'],[128,46,'guangzhou'],[146,53,'xiamen']]:
        print('*'*20)
        plt.rcParams['figure.figsize'] = (15, 5)
        plt.plot(ctm[:,i,a,b],'r--')
        plt.plot(new_ctm[:,i,a,b],'g--')
        plt.plot(obs[:,i,a,b],'k')
        plt.legend(['ctm','new ctm','obs'])
        plt.title(p_name[i] + ' : ' + name)
        plt.show()
# Out:
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
# ********************
